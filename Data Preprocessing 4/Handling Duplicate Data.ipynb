# %%
import pandas as pd

# %%
df=pd.read_csv("duplicated.csv")

# %%
df.head()
# Out:
#    ID      Name  Age     City  Marks
# 0  14     Nisha   20     Pune     93
# 1  40     Kriti   22  Kolkata     93
# 2  31  Abhishek   21    Delhi     79
# 3  12     Kavya   19   Jaipur     81
# 4  18     Pooja   23   Mumbai     89

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19     True
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27    False
# 28    False
# 29    False
# 30    False
# 31     True
# 32    False
# 33    False
# 34     True
# 35    False
# 36     True
# 37    False
# 38    False
# 39     True
# 40    False
# 41    False
# 42    False
# 43     True
# 44    False
# 45    False
# 46    False
# 47    False
# 48     True
# 49    False
# dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (40, 5)
